// %% [markdown]
// # Configurations
//
// Nightly toolchain is needed for `slas` to work, which is a linear algebra system written by me.
//
// Plotly is also needed for plotting data.

// %%
:toolchain nightly

:dep slas={git="https://github.com/unic0rn9k/slas"}
:dep plotly
:dep itertools-num

use slas::prelude::*;
use slas_backend::*;

extern crate plotly;
extern crate rand_distr;
extern crate itertools_num;
extern crate itertools;

use itertools_num::linspace;
use plotly::common::{
    ColorScale, ColorScalePalette, DashType, Fill, Font, Line, LineShape, Marker, Mode, Title,
};
use plotly::layout::{Axis, BarMode, Layout, Legend, TicksDirection};
use plotly::{Bar, NamedColor, Plot, Rgb, Rgba, Scatter};
use rand_distr::{Distribution, Normal, Uniform};
// Out:
// Toolchain: nightly

// %% [markdown]
// # Some example code
//
// For some reasone slas vectors needs type annotations when used in evcxr, even though this is not required normally...

// %%
let mut a: StaticCowVec<f32, 3> = moo![f32: 1, 2, 3];
let b: StaticCowVec<f32, 3> = moo![f32: 0..3];

println!("{}", b.static_backend::<Blas>().dot(&a.static_backend::<Blas>()));
// Out:
// 8

// %%
println!("{a:?}");
// Out:
// [1.0, 2.0, 3.0]

// %% [markdown]
// ## Generating and plotting a simple wave

// %%
let n: usize = 100;
let t: Vec<f64> = linspace(0., 400., n).collect();

let y: StaticCowVec<f32, 400> = moo![|n|
    (n as f32 / 6.).sin() + (n as f32 / 4.).sin()
; 400];

let trace = Scatter::new(t, **y).mode(Mode::Markers);
let mut plot = Plot::new();
plot.add_trace(trace);
let layout = Layout::new().height(800);
plot.set_layout(layout);
plot.notebook_display();
// Out:
// <div>
//     <div id="d2XTtiIHUufNb3F8IUCg" class="plotly-graph-div" style="height:100%; width:100%;"></div>
//     <script type="text/javascript">
//         require(['https://cdn.plot.ly/plotly-2.8.3.min.js'], function(Plotly) {
//             window.PLOTLYENV=window.PLOTLYENV || {};
//
//             if (document.getElementById("d2XTtiIHUufNb3F8IUCg")) {
//                 var trace_0 = {"type":"scatter","mode":"markers","x":[0.0,4.040404040404041,8.080808080808081,12.121212121212121,16.161616161616163,20.202020202020204,24.242424242424242,28.282828282828284,32.323232323232325,36.36363636363637,40.40404040404041,44.44444444444445,48.484848484848484,52.525252525252526,56.56565656565657,60.60606060606061,64.64646464646465,68.68686868686869,72.72727272727273,76.76767676767678,80.80808080808082,84.84848484848486,88.8888888888889,92.92929292929294,96.96969696969697,101.01010101010101,105.05050505050505,109.0909090909091,113.13131313131314,117.17171717171718,121.21212121212122,125.25252525252526,129.2929292929293,133.33333333333334,137.37373737373738,141.41414141414143,145.45454545454547,149.4949494949495,153.53535353535355,157.5757575757576,161.61616161616163,165.65656565656568,169.69696969696972,173.73737373737376,177.7777777777778,181.81818181818184,185.85858585858588,189.89898989898992,193.93939393939394,197.97979797979798,202.02020202020202,206.06060606060606,210.1010101010101,214.14141414141415,218.1818181818182,222.22222222222223,226.26262626262627,230.3030303030303,234.34343434343435,238.3838383838384,242.42424242424244,246.46464646464648,250.50505050505052,254.54545454545456,258.5858585858586,262.62626262626264,266.6666666666667,270.7070707070707,274.74747474747477,278.7878787878788,282.82828282828285,286.8686868686869,290.90909090909093,294.949494949495,298.989898989899,303.03030303030306,307.0707070707071,311.11111111111114,315.1515151515152,319.1919191919192,323.23232323232327,327.2727272727273,331.31313131313135,335.3535353535354,339.39393939393943,343.4343434343435,347.4747474747475,351.51515151515156,355.5555555555556,359.59595959595964,363.6363636363637,367.6767676767677,371.71717171717177,375.7575757575758,379.79797979797985,383.8383838383839,387.8787878787879,391.9191919191919,395.95959595959596,400.0],"y":[0.0,0.4133001,0.80662024,1.1610644,1.4598408,1.6891615,1.8389659,1.9034309,1.8812354,1.7755682,1.59388,1.3473957,1.0504174,0.7194652,0.3723027,0.026910782,-0.29952994,-0.59158885,-0.8364101,-1.0243642,-1.1494921,-1.2097178,-1.2068174,-1.1461577,-1.0362179,-0.88793176,-0.7138946,-0.5274861,-0.3419683,-0.16961426,-0.02092433,0.09602052,0.17602897,0.2170639,0.22028875,0.18989187,0.132703,0.057634167,-0.025023956,-0.104399204,-0.16987005,-0.21188486,-0.22270918,-0.19704562,-0.13249326,-0.029808044,0.107055604,0.27112186,0.4527853,0.6403916,0.8209723,0.98108625,1.107718,1.189172,1.2159029,1.181237,1.0819249,0.91848993,0.6953579,0.42073804,0.10626674,-0.23355955,-0.58214855,-0.92172015,-1.2342992,-1.5027496,-1.7117755,-1.8488328,-1.9048972,-1.8750386,-1.7587686,-1.5601358,-1.2875602,-0.95342124,-0.5734147,-0.16571344,0.2500055,0.65363,1.0257069,1.34849,1.6068966,1.7893095,1.8881716,1.900353,1.827263,1.6747005,1.45246,1.1737132,0.8542084,0.511336,0.16311336,-0.17284107,-0.480292,-0.74527097,-0.9567975,-1.1074113,-1.1934817,-1.2152679,-1.1767554,-1.0852501,-0.95079863,-0.7854371,-0.60233915,-0.41492218,-0.23595273,-0.07672322,0.05365467,0.14879614,0.20538872,0.22333074,0.2056421,0.15815583,0.08903377,0.00811024,-0.07387844,-0.14610866,-0.19850689,-0.22253567,-0.21186018,-0.16288263,-0.075086355,0.048840165,0.20308906,0.37904185,0.56578016,0.750762,0.9206301,1.0620905,1.1628156,1.2123133,1.2026888,1.1292721,0.99106055,0.79092467,0.5355934,0.2353999,-0.096218586,-0.44340485,-0.78873295,-1.1141837,-1.4021648,-1.6365306,-1.8035405,-1.8926876,-1.8973572,-1.8152663,-1.64866,-1.4042561,-1.0929217,-0.72911954,-0.33015054,0.08478449,0.4956188,0.88250256,1.2268903,1.5125357,1.7263539,1.8591148,1.9058992,1.8663101,1.7444334,1.5485346,1.2905271,0.9852394,0.64952475,0.30127692,-0.04160577,-0.36222723,-0.64561576,-0.8795271,-1.0550523,-1.1670097,-1.2141192,-1.1989183,-1.1274494,-1.0087512,-0.8541643,-0.6765146,-0.48923218,-0.3054462,-0.13712811,0.005666554,0.11541408,0.18754923,0.22069085,0.21664071,0.18015891,0.11855188,0.041074425,-0.04180173,-0.11918494,-0.18060538,-0.21682793,-0.220 ...
// var data = [trace_0];
// var layout = {"height":800};
//                 Plotly.newPlot(
//                     'd2XTtiIHUufNb3F8IUCg',
//                     data,
//                     layout,
//                     {"responsive": true}
//                 ).then(function(){
//                     var gd = document.getElementById('d2XTtiIHUufNb3F8IUCg');
//                     var x = new MutationObserver(function (mutations, observer) { {
//                             var display = window.getComputedStyle(gd).display;
//                             if (!display || display === 'none') { {
//                                 console.log([gd, 'removed!']);
//                                 Plotly.purge(gd);
//                                 observer.disconnect();
//                             } }
//                     } });
//
//                     // Listen for the removal of the full notebook cells
//                     var notebookContainer = gd.closest('#notebook-container');
//                     if (notebookContainer) { {
//                         x.observe(notebookContainer, {childList: true});
//                     } }
//
//                     // Listen for the clearing of the current output cell
//                     var outputEl = gd.closest('.output');
//                     if (outputEl) { {
//                         x.observe(outputEl, {childList: true});
//                     } } })
//             };
//         });
//             </script>
// </div>
