// %% [markdown]
// # Configurations
//
// Nightly toolchain is needed for `slas` to work, which is a linear algebra system written by me.
//
// [Plotly](https://lib.rs/plotly) and [itertools](https://lib.rs/itertools) is also needed for plotting data.

// %%
:toolchain nightly

:dep slas = { git = "https://github.com/unic0rn9k/slas", features = ["fast-floats"] }
:dep plotly
:dep itertools-num

#![allow(incomplete_features)]
#![feature(generic_const_exprs, test)]

use slas::prelude::*;
use slas_backend::*;

extern crate plotly;
extern crate rand_distr;
extern crate itertools_num;
extern crate itertools;

use itertools_num::linspace;
use plotly::common::{
    ColorScale, ColorScalePalette, DashType, Fill, Font, Line, LineShape, Marker, Mode, Title,
};
use plotly::layout::{Axis, BarMode, Layout, Legend, TicksDirection};
use plotly::{Bar, NamedColor, Plot, Rgb, Rgba, Scatter};
use rand_distr::{Distribution, Normal, Uniform};
// Out:
// Toolchain: nightly

// %% [markdown]
// # Some example code
//
// For some reasone slas vectors needs type annotations when used in evcxr, even though this is not required normally...

// %%
let mut a: StaticCowVec<f32, 3> = moo![f32: 1, 2, 3];
let b: StaticCowVec<f32, 3> = moo![f32: 0..3];

println!("{}", b.static_backend::<Blas>().dot(&a.static_backend::<Blas>()));
// Out:
// 8

// %%
println!("{a:?}");
// Out:
// [1.0, 2.0, 3.0]

// %% [markdown]
// # Defining some useful functions
//
// first we define a function for plotting a vector with index on the x-axis and values on the y-axis

// %%
extern crate serde;

fn plot_vector<const LEN: usize>(v: StaticVecRef<f32, LEN>){
    let t: Vec<f64> = linspace(0., LEN as f64, LEN).collect();
    let trace = Scatter::new(t, **v).mode(Mode::Markers);
    let mut plot = Plot::new();
    plot.add_trace(trace);
    let layout = Layout::new().height(v.iter().map(|n|*n as usize).max().unwrap());
    plot.set_layout(layout);
    plot.notebook_display();
}

// %% [markdown]
// ## Generating and plotting a simple wave

// %%
use fast_floats::*;

let y: StaticCowVec<f32, 512> = moo![|t|{
    let t = fast(t as f32) / fast(10.);
    *((t / 1.7).sin_() + (t / fast(3.5)).sin_())
}; 512];

plot_vector(y.moo_ref());
// Out:
// <div>
//     <div id="sSp70LI1XL2ff1sKFjT0" class="plotly-graph-div" style="height:100%; width:100%;"></div>
//     <script type="text/javascript">
//         require(['https://cdn.plot.ly/plotly-2.8.3.min.js'], function(Plotly) {
//             window.PLOTLYENV=window.PLOTLYENV || {};
//
//             if (document.getElementById("sSp70LI1XL2ff1sKFjT0")) {
//                 var trace_0 = {"type":"scatter","mode":"markers","x":[0.0,1.0019569471624266,2.003913894324853,3.0058708414872797,4.007827788649706,5.009784735812133,6.011741682974559,7.013698630136986,8.015655577299412,9.017612524461839,10.019569471624266,11.021526418786692,12.023483365949119,13.025440313111545,14.027397260273972,15.029354207436398,16.031311154598825,17.03326810176125,18.035225048923678,19.037181996086105,20.03913894324853,21.041095890410958,22.043052837573384,23.04500978473581,24.046966731898237,25.048923679060664,26.05088062622309,27.052837573385517,28.054794520547944,29.05675146771037,30.058708414872797,31.060665362035223,32.06262230919765,33.064579256360076,34.0665362035225,35.06849315068493,36.070450097847356,37.07240704500978,38.07436399217221,39.076320939334636,40.07827788649706,41.08023483365949,42.082191780821915,43.08414872798434,44.08610567514677,45.088062622309195,46.09001956947162,47.09197651663405,48.093933463796475,49.0958904109589,50.09784735812133,51.099804305283755,52.10176125244618,53.10371819960861,54.105675146771034,55.10763209393346,56.10958904109589,57.111545988258314,58.11350293542074,59.11545988258317,60.11741682974559,61.11937377690802,62.12133072407045,63.12328767123287,64.1252446183953,65.12720156555773,66.12915851272015,67.13111545988258,68.133072407045,69.13502935420743,70.13698630136986,71.13894324853229,72.14090019569471,73.14285714285714,74.14481409001957,75.14677103718199,76.14872798434442,77.15068493150685,78.15264187866927,79.1545988258317,80.15655577299412,81.15851272015655,82.16046966731898,83.1624266144814,84.16438356164383,85.16634050880626,86.16829745596868,87.17025440313111,88.17221135029354,89.17416829745596,90.17612524461839,91.17808219178082,92.18003913894324,93.18199608610567,94.1839530332681,95.18590998043052,96.18786692759295,97.18982387475538,98.1917808219178,99.19373776908023,100.19569471624266,101.19765166340508,102.19960861056751,103.20156555772994,104.20352250489236,105.20547945205479,106.20743639921722,107.20939334637964,108.21135029354207,109.2133072407045,110.21526418786692,111.21722113502935,112.21917808219177,113.2211350293542,114.22309197651663,115.22504892367905,116.22700587084148,117.22896281800391,118.23091976516633,119.23287671232876,120.23483365949119,121.23679060665361,122.23874755381604,123.24070450097847,124.2426614481409,125.24461839530332,126.24657534246575,127.24853228962817,128.2504892367906,129.25244618395303,130.25440313111545,131.25636007827788,132.2583170254403,133.26027397260273,134.26223091976516,135.26418786692759,136.26614481409,137.26810176125244,138.27005870841487,139.2720156555773,140.27397260273972,141.27592954990214,142.27788649706457,143.279843444227,144.28180039138942,145.28375733855185,146.28571428571428,147.2876712328767,148.28962818003913,149.29158512720156,150.29354207436398,151.2954990215264,152.29745596868884,153.29941291585126,154.3013698630137,155.30332681017612,156.30528375733854,157.30724070450097,158.3091976516634,159.31115459882582,160.31311154598825,161.31506849315068,162.3170254403131,163.31898238747553,164.32093933463796,165.32289628180038,166.3248532289628,167.32681017612524,168.32876712328766,169.3307240704501,170.33268101761252,171.33463796477494,172.33659491193737,173.3385518590998,174.34050880626222,175.34246575342465,176.34442270058707,177.3463796477495,178.34833659491193,179.35029354207435,180.35225048923678,181.3542074363992,182.35616438356163,183.35812133072406,184.3600782778865,185.3620352250489,186.36399217221134,187.36594911937377,188.3679060665362,189.36986301369862,190.37181996086105,191.37377690802347,192.3757338551859,193.37769080234833,194.37964774951075,195.38160469667318,196.3835616438356,197.38551859099803,198.38747553816046,199.38943248532289,200.3913894324853,201.39334637964774,202.39530332681016,203.3972602739726,204.39921722113502,205.40117416829744,206.40313111545987,207.4050880626223,208.40704500978472,209.40900195694715,210.41095890410958,211.412915851272,212.41487279843443,213.41682 ...

// %% [markdown]
// # Euler's identity

// %%
im(std::f32::consts::PI).exp_()
// Out:
// (-1 - 0.00000008742278im)

// %% [markdown]
// # Cooley-Tukey in python
// ```python
// def FFT(x):
//     N = len(x)
//     if N <= 1: return x
//     even = FFT(x[0::2])
//     odd = FFT(x[1::2])
//     T = [np.exp(-2j * np.pi * k / N) * odd[k] for k in range(N // 2)]
//     return [even[k] + T[k] for k in range(N // 2)] + \
//         [even[k] - T[k] for k in range(N // 2)]
//
// ```

// %% [markdown]
// # Cooley-Tukey in Rust
//
// This implementation of the cooley-tukey FFT algorithm is entirely statically allocated.
// Theoretically it should be able to just do one allocation (besides pointers),
// as

// %%
use std::f32::consts::PI;

// x    = pointer to input vector.
//
// o    = pointer to output vector.
//
// len  = length of ipnut and output vectors.
//       (This function will not check if the length is valid,
//        Which is why `fft` should always be used instead.)
//
// ofset = 2 ^ recursion depth (starts at 0).

unsafe fn unsafe_fft<const LEN: usize>(x: *const Complex<f32>, o: *mut Complex<f32>, len: usize, ofset: usize)
    -> *const Complex<f32>
{
    if len < 2{
        return x
    }
    
    // Recursively compute even and odd fourrier coefficient's.
    // The even fourrier coefficient will be stored at the right hand side of the vector,
    // hence why o.add(len/2) is used as the output pointer for the function call.
    let even = unsafe_fft::<LEN>(x, o.add(len/2), len/2, ofset * 2);
    
    // ofset is added to the input pointer, so the memory read from is shiftet to the right,
    // This is done because 0 is even.
    let odd = unsafe_fft::<LEN>(x.add(ofset), o, len/2, ofset * 2);
        
    for k in 0..len/2{
        // Memory adress where the k'th even fourrier coefficient is stored
        let even = *even.add(k);
        
        // Memory adress where the k'th odd fourrier coefficient is stored
        let odd = *odd.add(k);
        
        // This will compute the ω value,
        // which will temporarily be stored in the location of the positive fourrier coefficient.
        *o.add(k) = im(-2. * PI * k as f32 / len as f32).exp_();
                
        // After the negative fourrier coefficient is calculated, as to not overwrite ω,
        // which is also needed to compute the positive fourrier coefficient.
        *o.add(k+len/2) = even - *o.add(k) * odd;
        
        // Positive fourrier coefficient is computed.
        *o.add(k) = even + *o.add(k) * odd;
    }
    
    o
}

fn fft<const LEN: usize>(x: StaticVecRef<Complex<f32>, LEN>) -> [Complex<f32>; LEN]{
    assert_eq!(LEN & (LEN - 1), 0);
    let mut ret = **x;
    unsafe{ unsafe_fft::<LEN>(x.as_ptr(), ret.as_mut_ptr(), LEN, 1) };
    ret
}

// %%
let a = [re(1.), re(2.), re(3.), re(4.)];

let b = fft(a.moo_ref());

println!("{:#?}", b);
// 10.0 + 0.0im
// -2.0 + 2.0im
// -2.0 + 0.0im
// -2.0 - 2.0im
// Out:
// [
//     (10 + 0im),
//     (-1.9999999 + 2im),
//     (-2 + 0im),
//     (-2 - 2im),
// ]

// %%
const LEN: usize = 2_usize.pow(12);


let mut y_hat: [Complex<f32>; LEN] = [re(0f32); LEN];


for i in 0..y_hat.len(){
    let t = fast(i as f32) / fast(PI * 240.);
    y_hat[i] = re(*((t * 20.).cos_() + (t * 500.).cos_()));
}

y_hat = fft(y_hat.moo_ref());

let mut y: [f32; LEN] = [0f32; LEN];
for i in 0..y.len(){
    y[i] = y_hat[i].im.abs() / 2.
}

println!(r#"
    Highest frequency dettected between 18 and 600Hz : {}Hz // This should be 500Hz
    Highest frequency dettected between 0 and 600Hz  : {}Hz // This should be 20Hz
    Highest possible frequency in wave               : {}Hz // This should be 2^12Hz
    "#,
    y_hat[18..600].iter().enumerate().max_by_key(|(_, &value)| value.re as usize).map(|(idx, _)| idx).unwrap(),
    y_hat[0..600].iter().enumerate().max_by_key(|(_, &value)| value.re as usize).map(|(idx, _)| idx).unwrap(),
    y_hat.len(),
)
// Out:
//     Highest frequency dettected between 18 and 600Hz : 414Hz // This should be 500Hz
//     Highest frequency dettected between 0 and 600Hz  : 17Hz // This should be 20Hz
//     Highest possible frequency in wave               : 4096Hz // This should be 2^12Hz
// ()

// %%
plot_vector(y.moo_ref());
// Out:
// <div>
//     <div id="cT20IF1LzTS68hKfTNYD" class="plotly-graph-div" style="height:100%; width:100%;"></div>
//     <script type="text/javascript">
//         require(['https://cdn.plot.ly/plotly-2.8.3.min.js'], function(Plotly) {
//             window.PLOTLYENV=window.PLOTLYENV || {};
//
//             if (document.getElementById("cT20IF1LzTS68hKfTNYD")) {
